# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation

# %%
import os
cwd = os.getcwd()  # Get the current working directory (cwd)
files = os.listdir(cwd)  # Get all the files in that directory
print("Files in %r: %s" % (cwd, files))
# Out:
# Files in '/home/basalam1960/PycharmProjects/MST': ['.ipynb_checkpoints', 'Untitled.ipynb', 'diabetes.png', 'mst.csv', '.~lock.BSR.csv#', 'BSR.csv', '.idea', 'MST.py', 'venv']

# %%
col_names = ['paid_at', 'invoice_id','invoice_item_id', 'amount', 'user_province_id', 'user_province_name', 'user_city_id', 'user_city_name', 'city_population', 'city_population_percent', 'vendors', 'unique_user', 'total_user', 'product_count', 'agv_amount_city', 'coupon_discount', 'credit_amount', 'basalam_delivery_discount', 'basalam_product_discount', 'basalam_percent', 'delivery_cost_without_free_shipping', 'vendor_city_id', 'vendor_city_name', 'label']
# load dataset
BSR = pd.read_csv('/home/basalam1960/PycharmProjects/MST/BSR.csv', header=None, names=col_names)
BSR.head()
# Out:
#       paid_at  invoice_id  invoice_item_id   amount  user_province_id  \
# 0  2020-12-24     2333597          6551965   670700                10
# 1  2020-12-24     2333645          6551361   739000                 8
# 2  2020-12-24     2329404          6551169  1230000                19
# 3  2020-12-24     2329404          6551595  1230000                19
# 4  2020-12-24     2329404          6551930  1230000                19
#
#   user_province_name  user_city_id user_city_name  city_population  \
# 0              تهران          2052          تهران          8737510
# 1              ایلام          1979          ایلام           224590
# 2               فارس          2458          شیراز          1869001
# 3               فارس          2458          شیراز          1869001
# 4               فارس          2458          شیراز          1869001
#
#    city_population_percent  ...  agv_amount_city  coupon_discount  \
# 0                    10.92  ...           135138         574250.0
# ...

# %%
#split dataset in features and target variable
feature_cols = ['amount', 'user_province_id', 'user_city_id', 'city_population', 'city_population_percent', 'vendors', 'unique_user', 'total_user', 'product_count', 'agv_amount_city', 'coupon_discount', 'credit_amount', 'basalam_delivery_discount', 'basalam_product_discount', 'basalam_percent', 'delivery_cost_without_free_shipping', 'vendor_city_id']
X = BSR[feature_cols] # Features
y = BSR.label # Target variable
display (X)
# Out:
#          amount  user_province_id  user_city_id  city_population  \
# 0        670700                10          2052          8737510
# 1        739000                 8          1979           224590
# 2       1230000                19          2458          1869001
# 3       1230000                19          2458          1869001
# 4       1230000                19          2458          1869001
# ...         ...               ...           ...              ...
# 111393   439000                19          2458          1869001
# 111394   379000                15          2256          1302591
# 111395   206000                19          2489           323434
# 111396  1167000                10          2052          8737510
# 111397  2700000                13          2200           174495
#
#         city_population_percent  vendors  unique_user  total_user  \
# 0                         10.92    13031        45310       95080
# ...

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
import numpy as np

X_test.fillna(0)
# Out:
#          amount  user_province_id  user_city_id  city_population  \
# 21096   1275000                29          2795           531930
# 71086   2215000                12          2129           261324
# 84862         0                27          2734           956971
# 60520   2045000                29          2817           504298
# 94583   1620000                10          2052          8737510
# ...         ...               ...           ...              ...
# 42931     60000                13          2212          3372660
# 111359   828000                19          2458          1869001
# 37862   4477000                10          2052          8737510
# 3811     202000                21          2531          1292283
# 103336        0                10          2052          8737510
#
#         city_population_percent  vendors  unique_user  total_user  \
# 21096                      1.12      284          777        1395
# ...

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-168-effc1cc2cd4f> in <module>
#       3
#       4 # Train Decision Tree Classifer
# ----> 5 clf = clf.fit(X_train,y_train)
#       6
#       7 #Predict the response for test dataset
#
# ~/.local/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     896         """
#     897
# --> 898         super().fit(
#     899             X, y,
#     900             sample_weight=sample_weight,
#
# ~/.local/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     154             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     155             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 156             X, y = self._validate_data(X, y,
# ...

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-151-8937c08d392f> in <module>
#       1 # Model Accuracy, how often is the classifier correct?
# ----> 2 print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61
#      62     Parameters
# ---> 63     ----------
#      64     X : array or sparse matrix
#      65
#
# ~/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#
# ~/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     260     check_consistent_length(*result)
#     261     return result
# --> 262
#     263
# ...

# %%
# !pip3 install graphviz
# !pip3 install pydotplus
# !pip3 install -U scikit-learn
# Out:
# ...
#   Using cached scikit_learn-0.24.0-cp38-cp38-manylinux2010_x86_64.whl (24.9 MB)
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.20.3
#     Uninstalling scikit-learn-0.20.3:
#       Successfully uninstalled scikit-learn-0.20.3
# ...

# %%
# !pip3 install --upgrade scikit-learn==0.20.3
# Out:
# ...
#      |████████████████████████████████| 11.8 MB 4.7 MB/s eta 0:00:01
# ...
#   Created wheel for scikit-learn: filename=scikit_learn-0.20.3-cp38-cp38-linux_x86_64.whl size=17490598 sha256=07bc056fd12e3091f7ce8889150a9246797612068310ea7a0181746458900ec3
#   Stored in directory: /home/basalam1960/.cache/pip/wheels/ef/fe/c4/e049fcbdd11c70509176d65e45142a9dc70597a9ef45e61402
# Successfully built scikit-learn
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.24.0
#     Uninstalling scikit-learn-0.24.0:
#       Successfully uninstalled scikit-learn-0.24.0
# ...

# %%
# !pip3 install graphviz

# %%
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = feature_cols,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('diabetes.png')
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-153-e2816f0728af> in <module>
#       5
#       6 dot_data = StringIO()
# ----> 7 export_graphviz(clf, out_file=dot_data,
#       8                 filled=True, rounded=True,
#       9                 special_characters=True,feature_names = feature_cols,class_names=['0','1'])
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ...
